# %% [markdown]
# <u><center><h1>HOMEWORK 5</h1></center></u>
# <br></br>
# <center><h3>CS178</h3></center>
# <center><h3>Jeremy Parnell (jmparnel)</h3></center>
# <br></br>

# %%
from __future__ import division # For python 2.*

import numpy as np
import matplotlib.pyplot as plt
import mltools as ml

# Importing SVD
from scipy.linalg import svd

np.random.seed(0)
# %matplotlib inline

# %% [markdown]
# ## 1 Clustering

# %% [markdown]
# ### Problem 1.1

# %%
iris = np.genfromtxt("data/iris.txt",delimiter=None)
Y = iris[:,-1]
X = iris[:,0:2]

# %%
plt.scatter(iris[:, 0], iris[:, 1])
plt.show()

# %% [markdown]
# <p><b>I believe there are <u>THREE</u> clusters</b></p>

# %% [markdown]
# ### Problem 1.2

# %%
np.random.seed(1)
Z, mu, ssd = ml.cluster.kmeans(X, K=2, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 5.25633386,  3.17192434],
#        [ 6.65748012,  3.01305631]])

# %%
ssd
# Out:
# 57.877648396983034

# %%
np.random.seed(5)
Z, mu, ssd = ml.cluster.kmeans(X, K=2, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 5.25633386,  3.17192434],
#        [ 6.65748012,  3.01305631]])

# %%
ssd
# Out:
# 57.877648396983034

# %%
np.random.seed(10)
Z, mu, ssd = ml.cluster.kmeans(X, K=2, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 5.26553152,  3.1750583 ],
#        [ 6.66727319,  3.00689632]])

# %%
ssd
# Out:
# 57.879661961181966

# %%
np.random.seed(25)
Z, mu, ssd = ml.cluster.kmeans(X, K=2, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 5.26553152,  3.1750583 ],
#        [ 6.66727319,  3.00689632]])

# %%
ssd
# Out:
# 57.879661961181966

# %%
np.random.seed(50)
Z, mu, ssd = ml.cluster.kmeans(X, K=2, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 5.25633386,  3.17192434],
#        [ 6.65748012,  3.01305631]])

# %%
ssd
# Out:
# 57.877648396983034

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>

# %%
np.random.seed(1)
Z, mu, ssd = ml.cluster.kmeans(X, K=5, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.81807406,  3.25334884],
#        [ 6.89269775,  3.13209032],
#        [ 4.96746536,  2.41224227],
#        [ 5.94144253,  2.77510378],
#        [ 5.38068855,  3.79841024]])

# %%
ssd
# Out:
# 23.880791389200649

# %%
np.random.seed(5)
Z, mu, ssd = ml.cluster.kmeans(X, K=5, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.82762737,  3.00366273],
#        [ 6.6000011 ,  3.07254644],
#        [ 5.30205858,  3.74563501],
#        [ 7.48865109,  3.18027674],
#        [ 5.88590796,  2.7630639 ]])

# %%
ssd
# Out:
# 20.895826480459537

# %%
np.random.seed(10)
Z, mu, ssd = ml.cluster.kmeans(X, K=5, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.82051301,  3.07497615],
#        [ 5.34135623,  3.76005832],
#        [ 5.75189866,  2.66527872],
#        [ 7.16725067,  3.16740783],
#        [ 6.35531421,  2.9957928 ]])

# %%
ssd
# Out:
# 21.552866033263818

# %%
np.random.seed(25)
Z, mu, ssd = ml.cluster.kmeans(X, K=5, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 5.29655907,  3.72916088],
#        [ 7.48865109,  3.18027674],
#        [ 5.84127659,  2.74040561],
#        [ 4.81598649,  2.99304949],
#        [ 6.55537076,  3.05605677]])

# %%
ssd
# Out:
# 20.867217448173573

# %%
np.random.seed(50)
Z, mu, ssd = ml.cluster.kmeans(X, K=5, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.78729864,  3.13456819],
#        [ 6.34465265,  2.95546291],
#        [ 5.34135623,  3.76005832],
#        [ 5.64288227,  2.67468172],
#        [ 7.16725067,  3.16740783]])

# %%
ssd
# Out:
# 21.31426068787647

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>

# %%
np.random.seed(1)
Z, mu, ssd = ml.cluster.kmeans(X, K=20, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.91962697,  3.11284368],
#        [ 6.04994181,  3.10057129],
#        [ 4.69791892,  3.2228685 ],
#        [ 5.54525745,  2.52756757],
#        [ 4.73335962,  3.52270625],
#        [ 5.48192993,  3.86401723],
#        [ 6.90732209,  3.18562756],
#        [ 6.24197338,  2.38190155],
#        [ 5.63549636,  3.03960166],
#        [ 7.5706562 ,  2.90345969],
#        [ 5.7841228 ,  2.78028218],
#        [ 6.55470393,  2.89471501],
#        [ 5.73004043,  4.22888157],
#        [ 7.86504575,  3.87991495],
#        [ 5.06709497,  3.44326439],
#        [ 6.22460556,  2.83728385],
#        [ 4.92617625,  2.36007583],
#        [ 6.4276389 ,  3.30711204],
#        [ 5.25621198,  3.66669745],
#        [ 4.42775118,  3.07546772]])

# %%
ssd
# Out:
# 4.4611878219455834

# %%
np.random.seed(5)
Z, mu, ssd = ml.cluster.kmeans(X, K=20, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.91962697,  3.11284368],
#        [ 6.38027282,  3.32029684],
#        [ 5.26367066,  3.91086429],
#        [ 7.68066566,  2.87822646],
#        [ 6.26538064,  2.65884208],
#        [ 5.70487897,  2.62124604],
#        [ 7.86504575,  3.87991495],
#        [ 6.55470393,  2.89471501],
#        [ 4.43875073,  2.84435517],
#        [ 5.0809111 ,  3.48400148],
#        [ 5.72619378,  4.13525027],
#        [ 7.2097041 ,  3.6379432 ],
#        [ 6.83600131,  3.14869615],
#        [ 5.41300399,  3.57631519],
#        [ 7.20186806,  3.11093844],
#        [ 5.04162828,  2.42687425],
#        [ 6.180386  ,  2.28911687],
#        [ 4.68928931,  3.35902218],
#        [ 5.7078808 ,  2.99425266],
#        [ 6.17329331,  2.94060588]])

# %%
ssd
# Out:
# 4.3337626797529296

# %%
np.random.seed(10)
Z, mu, ssd = ml.cluster.kmeans(X, K=20, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.91820916,  3.20269671],
#        [ 5.7420976 ,  4.458073  ],
#        [ 6.180386  ,  2.28911687],
#        [ 7.27490666,  3.02004732],
#        [ 6.09138306,  2.99721529],
#        [ 4.5224878 ,  2.3244504 ],
#        [ 5.41300399,  3.57631519],
#        [ 5.74040914,  2.85655262],
#        [ 5.5538059 ,  4.02254667],
#        [ 5.07479684,  3.64657925],
#        [ 7.7884463 ,  2.6172729 ],
#        [ 6.83902565,  3.14713662],
#        [ 4.54675099,  3.17284617],
#        [ 6.4618892 ,  3.23445147],
#        [ 7.86504575,  3.87991495],
#        [ 5.54525745,  2.52756757],
#        [ 7.2097041 ,  3.6379432 ],
#        [ 5.00691394,  2.36720092],
#        [ 7.72649493,  2.99048503],
#        [ 6.43008809,  2.78210079]])

# %%
ssd
# Out:
# 4.7445959261196196

# %%
np.random.seed(25)
Z, mu, ssd = ml.cluster.kmeans(X, K=20, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.87068178,  3.14735872],
#        [ 7.86504575,  3.87991495],
#        [ 5.66770271,  2.98390148],
#        [ 4.46622834,  3.08812668],
#        [ 6.81406765,  2.70712855],
#        [ 5.73004043,  4.22888157],
#        [ 7.62803543,  2.88701547],
#        [ 6.07738378,  3.02774219],
#        [ 5.61203118,  2.54611957],
#        [ 5.37029515,  3.76905549],
#        [ 6.24197338,  2.38190155],
#        [ 4.73335962,  3.52270625],
#        [ 6.43734738,  2.89123586],
#        [ 4.96746536,  2.41224227],
#        [ 5.09954441,  3.48538492],
#        [ 5.90361711,  2.7437294 ],
#        [ 7.04233525,  3.16104747],
#        [ 7.2097041 ,  3.6379432 ],
#        [ 6.4276389 ,  3.30711204],
#        [ 6.76100485,  3.14862701]])

# %%
ssd
# Out:
# 4.3869553742529153

# %%
np.random.seed(50)
Z, mu, ssd = ml.cluster.kmeans(X, K=20, init='k++', max_iter=100)

# %%
mu
# Out:
# array([[ 4.87068178,  3.14735872],
#        [ 6.30060406,  2.43626502],
#        [ 5.18936358,  3.88568738],
#        [ 5.59650095,  2.53141736],
#        [ 6.55878858,  3.12589364],
#        [ 6.28223624,  3.39200374],
#        [ 5.85277887,  2.74192199],
#        [ 7.17083202,  3.25233498],
#        [ 7.86504575,  3.87991495],
#        [ 4.46622834,  3.08812668],
#        [ 5.0809111 ,  3.48400148],
#        [ 4.96746536,  2.41224227],
#        [ 5.63394197,  4.0814357 ],
#        [ 6.84585025,  3.15453893],
#        [ 6.43379447,  2.86157583],
#        [ 6.12469454,  2.95479231],
#        [ 4.73335962,  3.52270625],
#        [ 7.62803543,  2.88701547],
#        [ 5.69553324,  3.00841498],
#        [ 5.41300399,  3.57631519]])

# %%
ssd
# Out:
# 4.0839992789982338

# %% [markdown]
# <br></br>
# <br></br>
# <br></br>

# %%
np.random.seed(1)
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
Z, mu, ssd = ml.cluster.kmeans(X, K=2, init='k++', max_iter=100)

ax[0].scatter(iris[:, 0], iris[:, 1], c=Z)

ax[1].scatter(iris[:, 0], iris[:, 1], c=Z) # Plotting the data
ax[1].scatter(mu[:, 0], mu[:, 1], s=500, marker='x', facecolor='black', lw=8) 
plt.show()

# %%
np.random.seed(25)
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
Z, mu, ssd = ml.cluster.kmeans(X, K=5, init='k++', max_iter=100)

ax[0].scatter(iris[:, 0], iris[:, 1], c=Z)

ax[1].scatter(iris[:, 0], iris[:, 1], c=Z) # Plotting the data
ax[1].scatter(mu[:, 0], mu[:, 1], s=500, marker='x', facecolor='black', lw=8) 
plt.show()

# %%
np.random.seed(50)
fig, ax = plt.subplots(1, 2, figsize=(20, 8))
Z, mu, ssd = ml.cluster.kmeans(X, K=20, init='k++', max_iter=100)

ax[0].scatter(iris[:, 0], iris[:, 1], c=Z)

ax[1].scatter(iris[:, 0], iris[:, 1], c=Z) # Plotting the data
ax[1].scatter(mu[:, 0], mu[:, 1], s=500, marker='x', facecolor='black', lw=8) 
plt.show()

# %% [markdown]
# ### Problem 1.3

# %% [markdown]
# #### Single Linkage

# %%
Z, _ = ml.cluster.agglomerative(X, K = 2, method = "min")
print("K = 2")
ml.plotClassify2D(None,X,Z)
# Out:
# K = 2

# %%
Z, _ = ml.cluster.agglomerative(X, K = 5, method = "min")
print("K = 5")
ml.plotClassify2D(None,X,Z)
# Out:
# K = 5

# %%
Z, _ = ml.cluster.agglomerative(X, K = 20, method = "min")
print("K = 20")
ml.plotClassify2D(None,X,Z)
# Out:
# K = 20

# %% [markdown]
# #### Complete Linkage

# %%
Z, _ = ml.cluster.agglomerative(X, K = 2, method = "max")
print("K = 2")
ml.plotClassify2D(None,X,Z)
# Out:
# K = 2

# %%
Z, _ = ml.cluster.agglomerative(X, K = 5, method = "max")
print("K = 5")
ml.plotClassify2D(None,X,Z)
# Out:
# K = 5

# %%
Z, _ = ml.cluster.agglomerative(X, K = 20, method = "max")
print("K = 20")
ml.plotClassify2D(None,X,Z)
# Out:
# K = 20

# %% [markdown]
# ## 2 EigenFaces

# %%
X = np.genfromtxt("data/faces.txt", delimiter=None) # load face dataset

# %% [markdown]
# ### Problem 2.1

# %%
mu = np.mean(X,axis=0)
XO = X - mu
img = np.reshape(mu,(24,24)) # convert vectorized data to 24x24 image patches
plt.imshow( img.T , cmap="gray") 
plt.show()

# %% [markdown]
# ### Problem 2.2

# %%
U, S, V = svd(XO, full_matrices=False)
W = U.dot( np.diag(S) )

# %%
print("W: " + str(W.shape))
print("V: " + str(V.shape))
# Out:
# W: (4916L, 576L)
# V: (576L, 576L)

# %% [markdown]
# ### Problem 2.3

# %%
mse = np.zeros(10)
for k in range(10):
    XhatO = W[:,:k].dot(V[:k,:])
    mse[k] = np.mean((XO - XhatO)**2)
plt.plot(range(10),mse,'r-',linewidth=3)
plt.show()

# %% [markdown]
# ### Problem 2.4

# %%
for j in range(3):
    a = 2*np.median(np.abs(W[:,j])) 
    img1 = np.reshape(mu+a*V[j,:],(24,24))
    img2 = np.reshape(mu-a*V[j,:],(24,24))
    f, (ax1,ax2) = plt.subplots(1,2)
    ax1.imshow( img1.T , cmap="gray") 
    ax2.imshow( img2.T , cmap="gray") 
    plt.show()

# %% [markdown]
# ### Problem 2.5

# %%
kvals = np.array([5,10,50,100])

for i in range(2):
    i = np.random.randint(X.shape[1])
    a = X[i,:]
    a = np.reshape(a,(24,24))
    f,ax = plt.subplots(1,4)
    ax[0].imshow(a.T, cmap="gray")
    for b,c in enumerate(kvals):
        a = mu + W[i,0:c].dot(V[0:c,:])
        a = np.reshape(a,(24,24))
        ax[b].imshow(a.T, cmap="gray")
    plt.show()

# %% [markdown]
# ### Problem 2.6

# %%
import mltools.transforms
f, ax = plt.subplots(1, 1, figsize=(12, 8))
idx = np.random.choice(X.shape[0], 25, replace=False)
coord,params = ml.transforms.rescale( W[:,0:2] ) # normalize scale of "W" locations

for i in idx:
    # compute where to place image (scaled W values) & size
    loc = (coord[i,0],coord[i,0]+0.5, coord[i,1],coord[i,1]+0.5)
    img = np.reshape( X[i,:], (24,24) ) # reshape to square
    ax.imshow( img.T , cmap="gray", extent=loc)  
ax.axis([-2, 2, -2, 2]) # set axis to reasonable visual scale
plt.show()

# %% [markdown]
# ## Statement of Collaboration
